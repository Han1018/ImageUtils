# %% [markdown]
# <a href="https://colab.research.google.com/github/Han1018/ImageUtils/blob/master/preProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 影像前處理影像前處理

# %%
# -*- coding: utf-8 -*-
import cv2
import matplotlib.pyplot as plt

# %%
# 灰階
# ref : https://blog.csdn.net/kepp_smiling/article/details/106171355

image = cv2.imread('1.jpg', 0)
ret2, grayedImage = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
plt.imshow(grayedImage, 'gray')

# %%
# 濾波-雙邊濾波
# ref : https://www.itread01.com/content/1549199532.html
# https://www.it145.com/9/91993.html
image = grayedImage
img_bilater = cv2.bilateralFilter(image,9,75,75)
plt.imshow(img_bilater, 'gray')

# %%
# Ref: https://www.itread01.com/content/1546370641.html
# 型態學處理-closing(先膨脹再侵蝕)

# OpenCV定義的結構元素  
kernel = cv2.getStructuringElement(cv2.MORPH_RECT,(3, 3))  
# 膨脹影象
image = img_bilater
dilated = cv2.dilate(image,kernel)
# 腐蝕影象  
eroded = cv2.erode(dilated,kernel)
plt.imshow(eroded)

# %%
# Ref: https://www.itread01.com/content/1546370641.html
# 型態學處理-opening(先侵蝕再膨脹)

# OpenCV定義的結構元素  
kernel = cv2.getStructuringElement(cv2.MORPH_RECT,(3, 3))  
image = img_bilater
# 腐蝕影象  
eroded = cv2.erode(image,kernel)
# 膨脹影象
dilated = cv2.dilate(eroded,kernel)

plt.imshow(dilated)
